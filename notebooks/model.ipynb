# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Url = ''
final_dataset = pd.read_csv(Url, encoding='latin-1')
final_dataset
# Out:
#        city_development_index  relevent_experience  education_level  \
# 0                       0.920                    1              2.0
# 1                       0.776                    0              2.0
# 2                       0.624                    0              2.0
# 3                       0.789                    0              2.0
# 4                       0.767                    1              2.0
# ...                       ...                  ...              ...
# 19153                   0.878                    0              2.0
# 19154                   0.920                    1              2.0
# 19155                   0.920                    1              2.0
# 19156                   0.802                    1              2.0
# 19157                   0.855                    0              2.0
#
#        experience  last_new_job  target  training Impact
# 0             0.0           1.0       1           33.120
# ...
